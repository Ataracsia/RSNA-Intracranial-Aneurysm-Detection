# %% [markdown]
# # 1. Import

# %%
import pandas as pd

# %% [markdown]
# # 2. Configuration

# %%
class Configuration:
    
    model_path = '../results/swin-s-original-agg-meta-5folds-weightedloss-384-3-2025-10-09_19-09-44/predicted_labels.csv'
    label_names = [
        # 13 classes
        'Left Infraclinoid Internal Carotid Artery',
        'Right Infraclinoid Internal Carotid Artery',
        'Left Supraclinoid Internal Carotid Artery',
        'Right Supraclinoid Internal Carotid Artery',
        'Left Middle Cerebral Artery',
        'Right Middle Cerebral Artery',
        'Anterior Communicating Artery',
        'Left Anterior Cerebral Artery',
        'Right Anterior Cerebral Artery',
        'Left Posterior Communicating Artery',
        'Right Posterior Communicating Artery',
        'Basilar Tip',
        'Other Posterior Circulation',
        # 'Aneurysm Present',
        ]

# %%
CFG = Configuration()

# %% [markdown]
# # 3. Load

# %%
pred_df = pd.read_csv()

# %%
pred_df
# Out:
#                                       SeriesInstanceUID  \
# 0     1.2.826.0.1.3680043.8.498.10004044428023505108...
# 1     1.2.826.0.1.3680043.8.498.10022688097731894079...
# 2     1.2.826.0.1.3680043.8.498.10034081836061566510...
# 3     1.2.826.0.1.3680043.8.498.10035782880104673269...
# 4     1.2.826.0.1.3680043.8.498.10037266473301611864...
# ...                                                 ...
# 4343  1.2.826.0.1.3680043.8.498.99307097785439940586...
# 4344  1.2.826.0.1.3680043.8.498.99362685682423289873...
# 4345  1.2.826.0.1.3680043.8.498.99800061424469215274...
# 4346  1.2.826.0.1.3680043.8.498.99892990973227842737...
# 4347  1.2.826.0.1.3680043.8.498.99985209798463601651...
#
#       Left Infraclinoid Internal Carotid Artery  \
# 0                                      0.000003
# 1                                      0.000003
# 2                                      0.000003
# 3                                      0.000003
# ...

# %% [markdown]
# # 4. Analysis

# %%
for label_name in CFG.label_names:
    print('label_name:', label_name)
    print('==================================================================')
    print('Max pred:', pred_df[label_name].max())
    print('Min pred:', pred_df[label_name].min())
    print('\n')
# Out:
# label_name: Left Infraclinoid Internal Carotid Artery
# ...
# Max pred: 3.576278686523437e-06
# Min pred: 2.5033950805664062e-06
#
#
# label_name: Right Infraclinoid Internal Carotid Artery
# ...
# Max pred: 3.516674041748047e-06
# Min pred: 1.5497207641601562e-06
#
#
# label_name: Left Supraclinoid Internal Carotid Artery
# ...
# Max pred: 3.457069396972656e-06
# Min pred: 2.443790435791016e-06
#
#
# label_name: Right Supraclinoid Internal Carotid Artery
# ...
# Max pred: 3.337860107421875e-06
# Min pred: 2.384185791015625e-06
#
#
# label_name: Left Middle Cerebral Artery
# ...
# Max pred: 3.457069396972656e-06
# Min pred: 2.562999725341797e-06
#
#
# label_name: Right Middle Cerebral Artery
# ...
# Max pred: 3.6954879760742183e-06
# Min pred: 2.7418136596679688e-06
#
#
# label_name: Anterior Communicating Artery
# ...
# Max pred: 3.75509262084961e-06
# Min pred: 2.7418136596679688e-06
#
#
# label_name: Left Anterior Cerebral Artery
# ...
# Max pred: 3.2782554626464844e-06
# Min pred: 1.5497207641601562e-06
#
#
# ...
